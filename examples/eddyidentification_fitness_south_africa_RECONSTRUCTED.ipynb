# %%
# Importing all libraries.
from pylab import *
from netCDF4 import Dataset
# %matplotlib inline
import os
import cmocean as cm
from trackeddy.tracking import *
from trackeddy.datastruct import *
from trackeddy.geometryfunc import *
from trackeddy.init import *
from trackeddy.physics import *
from trackeddy.plotfunc import *

# %%
# Output data path
outputpath='/g/data3/hh5/tmp/akm157/mom01v5_kds75/output306/'
# Import SSH values to python environment.
ncfile=Dataset(outputpath+'rregionsouthern_ocean_daily_eta_t.nc')
eta=ncfile.variables['eta_t'][:]*100
# Import geographic coordinates (Lon,Lat)
lon=ncfile.variables['xt_ocean_sub01'][:]
lat=ncfile.variables['yt_ocean_sub01'][:]

# %%
# Import SSH 10 yrs mean values to python environment.
ncfile=Dataset('/home/156/jm5970/github/trackeddy/data.input/meanssh_10yrs_AEXP.nc')
ssh_mean=squeeze(ncfile.variables['SSH_mean'][:])
# Import geographic coordinates (Lon,Lat)
lon=ncfile.variables['Longitude'][:]
lat=ncfile.variables['Latitude'][:]

# %%
#Area in indexes, probably in the future it will be added an option for lon - lat coords.
eta=eta[0:60,300::,2900:]
ssh_mean=ssh_mean[300::,2900::]
lon=lon[2900::]
lat=lat[300::]
areamap=array([[0,len(lon)],[0,len(lat)]])
ssha=eta-ssh_mean
print(shape(eta))
# Out:
# (60, 631, 700)

# %% [markdown]
# # Default Values
#
# Eccentricity Fit = 0.8
#
# Ellipse Fit = 0.85
#
# Gauss Fit = 0.65

# %%
eddytd=analyseddyzt(eta,lon,lat,0,60,1,25,5,5,data_meant=ssh_mean,areamap=areamap,mask=''\
                    ,destdir='',physics='',eccenfit=0.8,ellipsrsquarefit=0.85,gaussrsquarefit=0.65,\
                    diagnostics=False,pprint=False)
# Out:
#  0% [===========================================================>]100% Time Elapsed: 175 s  Number of contours analysed: 6577

# %%
eddytdn=analyseddyzt(eta,lon,lat,0,60,1,-25,-5,-5,data_meant=ssh_mean,areamap=areamap,mask=''\
                    ,destdir='',physics='',eccenfit=0.8,ellipsrsquarefit=0.85,gaussrsquarefit=0.65,\
                    diagnostics=False,pprint=False)
# Out:
#  0% [===========================================================>]100% Time Elapsed: 138 s  Number of contours analysed: 5498

# %%
threshold=1
eddyp=reconstruct_syntetic(shape(eta),lon,lat,eddytd)
eddyp[eddyp>=5]=np.nan
eddyn=reconstruct_syntetic(shape(eta),lon,lat,eddytdn)
eddyn[eddyn<=-5]=np.nan
eddyfield=eddyp+eddyn

# %%
pcolormesh(lon,lat,eddyfield[0,:,:])
colorbar()
pcolormesh(lon,lat,ssha[0,:,:],shading='gouraud',cmap=cm.cm.balance,vmin=-40,vmax=40,alpha=0.1)

# %%
import matplotlib.pyplot as plt
import numpy as np
import matplotlib.gridspec as gridspec
from matplotlib import animation, rc
rc('animation', html='html5')

###########

fig = plt.figure(figsize=(10, 10),facecolor='white')
gs = gridspec.GridSpec(1, 1)

#############################

ax1 = plt.subplot(gs[0,0])

lonmm,latmm=np.meshgrid(lon,lat)

map = Basemap(projection='ortho',lat_0=mean(lat),lon_0=mean(lon),resolution='c',ax=ax1)
lonm,latm=map(lonmm,latmm)
map.drawmeridians(np.arange(0,360,30),labels=[1,1,0,0],fontsize=10)
map.drawparallels(np.arange(0,360,30),labels=[1,1,0,0],fontsize=10)
map.fillcontinents(color='black',lake_color='black')
map.drawcoastlines()
map.drawcoastlines()

#quad2 = ax1.pcolormesh(lonm,latm,eddyfield[0,:,:],shading='gouraud',cmap=cm.cm.balance,\
#              vmin=-40,vmax=40)


def init():
    quad1.set_array([])
    quad2.set_array([])
    return quad1,quad2

def animate(iter):
    #ax1.contourf(lonm,latm,ssha[0,:,:],shading='gouraud',cmap=cm.cm.balance,vmin=-40,vmax=40,alpha=0.1)
    ax1.contourf(lonm,latm,ssha[iter,:,:],shading='gouraud',cmap=cm.cm.oxy,vmin=-40,vmax=40,alpha=0.4)
    ax1.contourf(lonm,latm,eddyfield[iter,:,:],shading='gouraud',cmap=cm.cm.balance,\
              vmin=-40,vmax=40,alpha=0.9)
    #quad2.set_array(ssha[iter,:,:].ravel())
    #quad1.set_array(eddyfield[iter,:,:].ravel())
    
    #ax1.pcolormesh(lonm,latm,eddyfield[iter,:,:],shading='gouraud',cmap=cm.cm.balance,vmin=-40,vmax=40,alpha=1)
    ax1.set_title('%03d'%(iter))
    
    #quad2.set_array(eddyfield[iter,:,:].ravel())
    return

gs.tight_layout(fig)

anim2 = animation.FuncAnimation(fig,animate,frames=60,interval=100,blit=False,repeat=True)
plt.close()
anim2
# Out:
# 'Warning: Cannot label meridians on full-disk
#                 Geostationary, Orthographic or Azimuthal equidistant basemap
#                 Warning: Cannot label parallels on Orthographic basemap
# <video width="720" height="720" controls autoplay loop>
#   <source type="video/mp4" src="...

# %% [markdown]
# # Default Values
#
# Eccentricity Fit = 0.6
#
# Ellipse Fit = 0.85
#
# Gauss Fit = 0.65

# %%
eddytd=analyseddyzt(eta,lon,lat,0,60,1,25,5,5,data_meant=ssh_mean,areamap=areamap,mask=''\
                    ,destdir='',physics='',eccenfit=0.75,ellipsrsquarefit=0.85,gaussrsquarefit=0.65,\
                    diagnostics=False,pprint=False)
# Out:
#  0% [===========================================================>]100% Time Elapsed: 151 s  Number of contours analysed: 6577

# %%
eddytdn=analyseddyzt(eta,lon,lat,0,60,1,-25,-5,-5,data_meant=ssh_mean,areamap=areamap,mask=''\
                    ,destdir='',physics='',eccenfit=0.75,ellipsrsquarefit=0.85,gaussrsquarefit=0.65,\
                    diagnostics=False,pprint=False)
# Out:
#  0% [===========================================================>]100% Time Elapsed: 121 s  Number of contours analysed: 5498

# %%
threshold=1
eddyp=reconstruct_syntetic(shape(eta),lon,lat,eddytd)
eddyp[eddyp>=5]=np.nan
eddyn=reconstruct_syntetic(shape(eta),lon,lat,eddytdn)
eddyn[eddyn<=-5]=np.nan
eddyfield=eddyp+eddyn

# %%
import matplotlib.pyplot as plt
import numpy as np
import matplotlib.gridspec as gridspec
from matplotlib import animation, rc
rc('animation', html='html5')

###########

fig = plt.figure(figsize=(10, 10),facecolor='white')
gs = gridspec.GridSpec(1, 1)

#############################

ax1 = plt.subplot(gs[0,0])

lonmm,latmm=np.meshgrid(lon,lat)

map = Basemap(projection='ortho',lat_0=mean(lat),lon_0=mean(lon),resolution='c',ax=ax1)
lonm,latm=map(lonmm,latmm)
map.drawmeridians(np.arange(0,360,30),labels=[1,1,0,0],fontsize=10)
map.drawparallels(np.arange(0,360,30),labels=[1,1,0,0],fontsize=10)
map.fillcontinents(color='black',lake_color='black')
map.drawcoastlines()
map.drawcoastlines()

#quad2 = ax1.pcolormesh(lonm,latm,eddyfield[0,:,:],shading='gouraud',cmap=cm.cm.balance,\
#              vmin=-40,vmax=40)


def init():
    quad1.set_array([])
    quad2.set_array([])
    return quad1,quad2

def animate(iter):
    #ax1.contourf(lonm,latm,ssha[0,:,:],shading='gouraud',cmap=cm.cm.balance,vmin=-40,vmax=40,alpha=0.1)
    ax1.contourf(lonm,latm,ssha[iter,:,:],shading='gouraud',cmap=cm.cm.oxy,vmin=-40,vmax=40,alpha=0.5)
    ax1.contourf(lonm,latm,eddyfield[iter,:,:],shading='gouraud',cmap=cm.cm.balance,\
              vmin=-40,vmax=40,alpha=0.9)
    #quad2.set_array(ssha[iter,:,:].ravel())
    #quad1.set_array(eddyfield[iter,:,:].ravel())
    
    #ax1.pcolormesh(lonm,latm,eddyfield[iter,:,:],shading='gouraud',cmap=cm.cm.balance,vmin=-40,vmax=40,alpha=1)
    ax1.set_title('%03d'%(iter))
    
    #quad2.set_array(eddyfield[iter,:,:].ravel())
    return

gs.tight_layout(fig)

anim2 = animation.FuncAnimation(fig,animate,frames=60,interval=100,blit=False,repeat=True)
plt.close()
anim2
# Out:
# 'Warning: Cannot label meridians on full-disk
#                 Geostationary, Orthographic or Azimuthal equidistant basemap
#                 Warning: Cannot label parallels on Orthographic basemap
# <video width="720" height="720" controls autoplay loop>
#   <source type="video/mp4" src="...

# %% [markdown]
# # Default Values
#
# Eccentricity Fit = 0.8
#
# Ellipse Fit = 0.5
#
# Gauss Fit = 0.65

# %%
eddytd=analyseddyzt(eta,lon,lat,0,60,1,25,5,5,data_meant=ssh_mean,areamap=areamap,mask=''\
                    ,destdir='',physics='',eccenfit=0.8,ellipsrsquarefit=0.5,gaussrsquarefit=0.65,\
                    diagnostics=False,pprint=False)
# Out:
#  0% [===========================================================>]100% Time Elapsed: 229 s  Number of contours analysed: 6577

# %%
eddytdn=analyseddyzt(eta,lon,lat,0,60,1,-25,-5,-5,data_meant=ssh_mean,areamap=areamap,mask=''\
                    ,destdir='',physics='',eccenfit=0.8,ellipsrsquarefit=0.5,gaussrsquarefit=0.65,\
                    diagnostics=False,pprint=False)
# Out:
#  0% [===========================================================>]100% Time Elapsed: 162 s  Number of contours analysed: 5498

# %%
threshold=1
eddyp=reconstruct_syntetic(shape(eta),lon,lat,eddytd)
eddyp[eddyp>=5]=np.nan
eddyn=reconstruct_syntetic(shape(eta),lon,lat,eddytdn)
eddyn[eddyn<=-5]=np.nan
eddyfield=eddyp+eddyn

# %%
#pcolormesh(eddysplot[0,:,:])

# %%
import matplotlib.pyplot as plt
import numpy as np
import matplotlib.gridspec as gridspec
from matplotlib import animation, rc
rc('animation', html='html5')

###########

fig = plt.figure(figsize=(10, 10),facecolor='white')
gs = gridspec.GridSpec(1, 1)

#############################

ax1 = plt.subplot(gs[0,0])

lonmm,latmm=np.meshgrid(lon,lat)

map = Basemap(projection='ortho',lat_0=mean(lat),lon_0=mean(lon),resolution='c',ax=ax1)
lonm,latm=map(lonmm,latmm)
map.drawmeridians(np.arange(0,360,30),labels=[1,1,0,0],fontsize=10)
map.drawparallels(np.arange(0,360,30),labels=[1,1,0,0],fontsize=10)
map.fillcontinents(color='black',lake_color='black')
map.drawcoastlines()
map.drawcoastlines()

#quad2 = ax1.pcolormesh(lonm,latm,eddyfield[0,:,:],shading='gouraud',cmap=cm.cm.balance,\
#              vmin=-40,vmax=40)


def init():
    quad1.set_array([])
    quad2.set_array([])
    return quad1,quad2

def animate(iter):
    #ax1.contourf(lonm,latm,ssha[0,:,:],shading='gouraud',cmap=cm.cm.balance,vmin=-40,vmax=40,alpha=0.1)
    ax1.contourf(lonm,latm,ssha[iter,:,:],shading='gouraud',cmap=cm.cm.oxy,vmin=-40,vmax=40,alpha=0.5)
    ax1.contourf(lonm,latm,eddyfield[iter,:,:],shading='gouraud',cmap=cm.cm.balance,\
              vmin=-40,vmax=40,alpha=0.9)
    #quad2.set_array(ssha[iter,:,:].ravel())
    #quad1.set_array(eddyfield[iter,:,:].ravel())
    
    #ax1.pcolormesh(lonm,latm,eddyfield[iter,:,:],shading='gouraud',cmap=cm.cm.balance,vmin=-40,vmax=40,alpha=1)
    ax1.set_title('%03d'%(iter))
    
    #quad2.set_array(eddyfield[iter,:,:].ravel())
    return

gs.tight_layout(fig)

anim2 = animation.FuncAnimation(fig,animate,frames=60,interval=100,blit=False,repeat=True)
plt.close()
anim2
# Out:
# 'Warning: Cannot label meridians on full-disk
#                 Geostationary, Orthographic or Azimuthal equidistant basemap
#                 Warning: Cannot label parallels on Orthographic basemap
# <video width="720" height="720" controls autoplay loop>
#   <source type="video/mp4" src="...

# %% [markdown]
# # Default Values
#
# Eccentricity Fit = 0.8
#
# Ellipse Fit = 0.85
#
# Gauss Fit = 0.90

# %%
eddytd=analyseddyzt(eta,lon,lat,0,60,1,25,5,5,data_meant=ssh_mean,areamap=areamap,mask=''\
                    ,destdir='',physics='',eccenfit=0.8,ellipsrsquarefit=0.85,gaussrsquarefit=0.9,\
                    diagnostics=False,pprint=False)
# Out:
#  0% [===========================================================>]100% Time Elapsed: 161 s  Number of contours analysed: 6577

# %%
eddytdn=analyseddyzt(eta,lon,lat,0,60,1,-25,-5,-5,data_meant=ssh_mean,areamap=areamap,mask=''\
                    ,destdir='',physics='',eccenfit=0.8,ellipsrsquarefit=0.85,gaussrsquarefit=0.9,\
                    diagnostics=False,pprint=False)
# Out:
#  0% [===========================================================>]100% Time Elapsed: 128 s  Number of contours analysed: 5498

# %%
threshold=1
eddyp=reconstruct_syntetic(shape(eta),lon,lat,eddytd)
eddyp[eddyp>=5]=np.nan
eddyn=reconstruct_syntetic(shape(eta),lon,lat,eddytdn)
eddyn[eddyn<=-5]=np.nan
eddyfield=eddyp+eddyn

# %%
import matplotlib.pyplot as plt
import numpy as np
import matplotlib.gridspec as gridspec
from matplotlib import animation, rc
rc('animation', html='html5')

###########

fig = plt.figure(figsize=(10, 10),facecolor='white')
gs = gridspec.GridSpec(1, 1)

#############################

ax1 = plt.subplot(gs[0,0])

lonmm,latmm=np.meshgrid(lon,lat)

map = Basemap(projection='ortho',lat_0=mean(lat),lon_0=mean(lon),resolution='c',ax=ax1)
lonm,latm=map(lonmm,latmm)
map.drawmeridians(np.arange(0,360,30),labels=[1,1,0,0],fontsize=10)
map.drawparallels(np.arange(0,360,30),labels=[1,1,0,0],fontsize=10)
map.fillcontinents(color='black',lake_color='black')
map.drawcoastlines()
map.drawcoastlines()

#quad2 = ax1.pcolormesh(lonm,latm,eddyfield[0,:,:],shading='gouraud',cmap=cm.cm.balance,\
#              vmin=-40,vmax=40)


def init():
    quad1.set_array([])
    quad2.set_array([])
    return quad1,quad2

def animate(iter):
    #ax1.contourf(lonm,latm,ssha[0,:,:],shading='gouraud',cmap=cm.cm.balance,vmin=-40,vmax=40,alpha=0.1)
    ax1.contourf(lonm,latm,ssha[iter,:,:],shading='gouraud',cmap=cm.cm.oxy,vmin=-40,vmax=40,alpha=0.5)
    ax1.contourf(lonm,latm,eddyfield[iter,:,:],shading='gouraud',cmap=cm.cm.balance,\
              vmin=-40,vmax=40,alpha=0.9)
    #quad2.set_array(ssha[iter,:,:].ravel())
    #quad1.set_array(eddyfield[iter,:,:].ravel())
    
    #ax1.pcolormesh(lonm,latm,eddyfield[iter,:,:],shading='gouraud',cmap=cm.cm.balance,vmin=-40,vmax=40,alpha=1)
    ax1.set_title('%03d'%(iter))
    
    #quad2.set_array(eddyfield[iter,:,:].ravel())
    return

gs.tight_layout(fig)

anim2 = animation.FuncAnimation(fig,animate,frames=60,interval=100,blit=False,repeat=True)
plt.close()
anim2
# Out:
# 'Warning: Cannot label meridians on full-disk
#                 Geostationary, Orthographic or Azimuthal equidistant basemap
#                 Warning: Cannot label parallels on Orthographic basemap
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# /g/data3/hh5/public/apps/miniconda3/envs/analysis3/lib/python3.6/site-packages/IPython/core/formatters.py in __call__(self, obj)
#     343             method = get_real_method(obj, self.print_method)
#     344             if method is not None:
# --> 345                 return method()
#     346             return None
#     347         else:
#
# ~/.local/lib/python3.6/site-packages/matplotlib/animation.py in _repr_html_(self)
#    1482         fmt = rcParams['animation.html']
#    1483         if fmt == 'html5':
# -> 1484             return self.to_html5_video()
#    1485         elif fmt == 'jshtml':
#    1486             return self.to_jshtml()
#
# ~/.local/lib/python3.6/site-packages/matplotlib/animation.py in to_html5_video(self, embed_limit)
#    1411                                 bitrate=rcParams['animation.bitrate'],
#    1412                                 fps=1000. / self._interval)
# -> 1413                 self.save(f.name, writer=writer)
#    1414
#    1415             # Now open and base64 encode
#
# ~/.local/lib/python3.6/site-packages/matplotlib/animation.py in save(self, filename, writer, fps, dpi, codec, bitrate, extra_args, metadata, extra_anim, savefig_kwargs)
#    1249                                level='helpful')
#    1250                 rcParams['savefig.bbox'] = None
# -> 1251             with writer.saving(self._fig, filename, dpi):
#    1252                 for anim in all_anim:
#    1253                     # Clear the initial frame
#
# /g/data3/hh5/public/apps/miniconda3/envs/analysis3/lib/python3.6/contextlib.py in __enter__(self)
#      79     def __enter__(self):
#      80         try:
# ---> 81             return next(self.gen)
#      82         except StopIteration:
#      83             raise RuntimeError("generator didn't yield") from None
#
# ~/.local/lib/python3.6/site-packages/matplotlib/animation.py in saving(self, fig, outfile, dpi, *args, **kwargs)
#     231         '''
#     232         # This particular sequence is what contextlib.contextmanager wants
# --> 233         self.setup(fig, outfile, dpi, *args, **kwargs)
#     234         try:
#     235             yield self
#
# ~/.local/lib/python3.6/site-packages/matplotlib/animation.py in setup(self, fig, outfile, dpi)
#     347         # Run here so that grab_frame() can write the data to a pipe. This
#     348         # eliminates the need for temp files.
# --> 349         self._run()
#     350
#     351     def _run(self):
#
# ~/.local/lib/python3.6/site-packages/matplotlib/animation.py in _run(self)
#     363                                       stdout=output, stderr=output,
#     364                                       stdin=subprocess.PIPE,
# --> 365                                       creationflags=subprocess_creation_flags)
#     366
#     367     def finish(self):
#
# /g/data3/hh5/public/apps/miniconda3/envs/analysis3/lib/python3.6/subprocess.py in __init__(self, args, bufsize, executable, stdin, stdout, stderr, preexec_fn, close_fds, shell, cwd, env, universal_newlines, startupinfo, creationflags, restore_signals, start_new_session, pass_fds, encoding, errors)
#     707                                 c2pread, c2pwrite,
#     708                                 errread, errwrite,
# --> 709                                 restore_signals, start_new_session)
#     710         except:
#     711             # Cleanup if the child failed starting.
#
# /g/data3/hh5/public/apps/miniconda3/envs/analysis3/lib/python3.6/subprocess.py in _execute_child(self, args, executable, preexec_fn, close_fds, pass_fds, cwd, env, startupinfo, creationflags, shell, p2cread, p2cwrite, c2pread, c2pwrite, errread, errwrite, restore_signals, start_new_session)
#    1273                             errread, errwrite,
#    1274                             errpipe_read, errpipe_write,
# -> 1275                             restore_signals, start_new_session, preexec_fn)
#    1276                     self._child_created = True
#    1277                 finally:
#
# OSError: [Errno 12] Cannot allocate memory

# %% [markdown]
# # Default Values
#
# Eccentricity Fit = 1
#
# Ellipse Fit = 0.85
#
# Gauss Fit = 0.85

# %%
eddytd=analyseddyzt(eta,lon,lat,0,60,1,25,5,5,data_meant=ssh_mean,areamap=areamap,mask=''\
                    ,destdir='',physics='',eccenfit=1,ellipsrsquarefit=0.85,gaussrsquarefit=0.85,\
                    diagnostics=False,pprint=False)
# Out:
#  0% [===========================================================>]100% Time Elapsed: 275 s  Number of contours analysed: 6577

# %%
eddytdn=analyseddyzt(eta,lon,lat,0,60,1,-25,-5,-5,data_meant=ssh_mean,areamap=areamap,mask=''\
                    ,destdir='',physics='',eccenfit=1,ellipsrsquarefit=0.85,gaussrsquarefit=0.85,\
                    diagnostics=False,pprint=False)
# Out:
#  0% [===========================================================>]100% Time Elapsed: 208 s  Number of contours analysed: 5498

# %%
threshold=1
eddyp=reconstruct_syntetic(shape(eta),lon,lat,eddytd)
eddyp[eddyp>=5]=np.nan
eddyn=reconstruct_syntetic(shape(eta),lon,lat,eddytdn)
eddyn[eddyn<=-5]=np.nan
eddyfield=eddyp+eddyn

# %%
import matplotlib.pyplot as plt
import numpy as np
import matplotlib.gridspec as gridspec
from matplotlib import animation, rc
rc('animation', html='html5')

###########

fig = plt.figure(figsize=(10, 10),facecolor='white')
gs = gridspec.GridSpec(1, 1)

#############################

ax1 = plt.subplot(gs[0,0])

lonmm,latmm=np.meshgrid(lon,lat)

map = Basemap(projection='ortho',lat_0=mean(lat),lon_0=mean(lon),resolution='c',ax=ax1)
lonm,latm=map(lonmm,latmm)
map.drawmeridians(np.arange(0,360,30),labels=[1,1,0,0],fontsize=10)
map.drawparallels(np.arange(0,360,30),labels=[1,1,0,0],fontsize=10)
map.fillcontinents(color='black',lake_color='black')
map.drawcoastlines()
map.drawcoastlines()

#quad2 = ax1.pcolormesh(lonm,latm,eddyfield[0,:,:],shading='gouraud',cmap=cm.cm.balance,\
#              vmin=-40,vmax=40)


def init():
    quad1.set_array([])
    quad2.set_array([])
    return quad1,quad2

def animate(iter):
    #ax1.contourf(lonm,latm,ssha[0,:,:],shading='gouraud',cmap=cm.cm.balance,vmin=-40,vmax=40,alpha=0.1)
    ax1.contourf(lonm,latm,ssha[iter,:,:],shading='gouraud',cmap=cm.cm.oxy,vmin=-40,vmax=40,alpha=0.5)
    ax1.contourf(lonm,latm,eddyfield[iter,:,:],shading='gouraud',cmap=cm.cm.balance,\
              vmin=-40,vmax=40,alpha=0.9)
    #quad2.set_array(ssha[iter,:,:].ravel())
    #quad1.set_array(eddyfield[iter,:,:].ravel())
    
    #ax1.pcolormesh(lonm,latm,eddyfield[iter,:,:],shading='gouraud',cmap=cm.cm.balance,vmin=-40,vmax=40,alpha=1)
    ax1.set_title('%03d'%(iter))
    
    #quad2.set_array(eddyfield[iter,:,:].ravel())
    return

gs.tight_layout(fig)

anim2 = animation.FuncAnimation(fig,animate,frames=60,interval=100,blit=False,repeat=True)
plt.close()
anim2
# Out:
# 'Warning: Cannot label meridians on full-disk
#                 Geostationary, Orthographic or Azimuthal equidistant basemap
#                 Warning: Cannot label parallels on Orthographic basemap
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# /g/data3/hh5/public/apps/miniconda3/envs/analysis3/lib/python3.6/site-packages/IPython/core/formatters.py in __call__(self, obj)
#     343             method = get_real_method(obj, self.print_method)
#     344             if method is not None:
# --> 345                 return method()
#     346             return None
#     347         else:
#
# ~/.local/lib/python3.6/site-packages/matplotlib/animation.py in _repr_html_(self)
#    1482         fmt = rcParams['animation.html']
#    1483         if fmt == 'html5':
# -> 1484             return self.to_html5_video()
#    1485         elif fmt == 'jshtml':
#    1486             return self.to_jshtml()
#
# ~/.local/lib/python3.6/site-packages/matplotlib/animation.py in to_html5_video(self, embed_limit)
#    1411                                 bitrate=rcParams['animation.bitrate'],
#    1412                                 fps=1000. / self._interval)
# -> 1413                 self.save(f.name, writer=writer)
#    1414
#    1415             # Now open and base64 encode
#
# ~/.local/lib/python3.6/site-packages/matplotlib/animation.py in save(self, filename, writer, fps, dpi, codec, bitrate, extra_args, metadata, extra_anim, savefig_kwargs)
#    1249                                level='helpful')
#    1250                 rcParams['savefig.bbox'] = None
# -> 1251             with writer.saving(self._fig, filename, dpi):
#    1252                 for anim in all_anim:
#    1253                     # Clear the initial frame
#
# /g/data3/hh5/public/apps/miniconda3/envs/analysis3/lib/python3.6/contextlib.py in __enter__(self)
#      79     def __enter__(self):
#      80         try:
# ---> 81             return next(self.gen)
#      82         except StopIteration:
#      83             raise RuntimeError("generator didn't yield") from None
#
# ~/.local/lib/python3.6/site-packages/matplotlib/animation.py in saving(self, fig, outfile, dpi, *args, **kwargs)
#     231         '''
#     232         # This particular sequence is what contextlib.contextmanager wants
# --> 233         self.setup(fig, outfile, dpi, *args, **kwargs)
#     234         try:
#     235             yield self
#
# ~/.local/lib/python3.6/site-packages/matplotlib/animation.py in setup(self, fig, outfile, dpi)
#     347         # Run here so that grab_frame() can write the data to a pipe. This
#     348         # eliminates the need for temp files.
# --> 349         self._run()
#     350
#     351     def _run(self):
#
# ~/.local/lib/python3.6/site-packages/matplotlib/animation.py in _run(self)
#     363                                       stdout=output, stderr=output,
#     364                                       stdin=subprocess.PIPE,
# --> 365                                       creationflags=subprocess_creation_flags)
#     366
#     367     def finish(self):
#
# /g/data3/hh5/public/apps/miniconda3/envs/analysis3/lib/python3.6/subprocess.py in __init__(self, args, bufsize, executable, stdin, stdout, stderr, preexec_fn, close_fds, shell, cwd, env, universal_newlines, startupinfo, creationflags, restore_signals, start_new_session, pass_fds, encoding, errors)
#     707                                 c2pread, c2pwrite,
#     708                                 errread, errwrite,
# --> 709                                 restore_signals, start_new_session)
#     710         except:
#     711             # Cleanup if the child failed starting.
#
# /g/data3/hh5/public/apps/miniconda3/envs/analysis3/lib/python3.6/subprocess.py in _execute_child(self, args, executable, preexec_fn, close_fds, pass_fds, cwd, env, startupinfo, creationflags, shell, p2cread, p2cwrite, c2pread, c2pwrite, errread, errwrite, restore_signals, start_new_session)
#    1273                             errread, errwrite,
#    1274                             errpipe_read, errpipe_write,
# -> 1275                             restore_signals, start_new_session, preexec_fn)
#    1276                     self._child_created = True
#    1277                 finally:
#
# OSError: [Errno 12] Cannot allocate memory

# %% [markdown]
# # Default Values
#
# Eccentricity Fit = 0.95
#
# Ellipse Fit = 0.85
#
# Gauss Fit = 0.85

# %%
eddytd=analyseddyzt(eta,lon,lat,0,60,1,25,5,5,data_meant=ssh_mean,areamap=areamap,mask=''\
                    ,destdir='',physics='',eccenfit=0.95,ellipsrsquarefit=0.85,gaussrsquarefit=0.85,\
                    diagnostics=False,pprint=False)
# Out:
#  0% [===========================================================>]100% Time Elapsed: 267 s  Number of contours analysed: 6577

# %%
eddytdn=analyseddyzt(eta,lon,lat,0,60,1,-25,-5,-5,data_meant=ssh_mean,areamap=areamap,mask=''\
                    ,destdir='',physics='',eccenfit=0.95,ellipsrsquarefit=0.85,gaussrsquarefit=0.85,\
                    diagnostics=False,pprint=False)
# Out:
#  0% [===========================================================>]100% Time Elapsed: 201 s  Number of contours analysed: 5498

# %%
threshold=1
eddyp=reconstruct_syntetic(shape(eta),lon,lat,eddytd)
eddyp[eddyp>=5]=np.nan
eddyn=reconstruct_syntetic(shape(eta),lon,lat,eddytdn)
eddyn[eddyn<=-5]=np.nan
eddyfield=eddyp+eddyn

# %%
import matplotlib.pyplot as plt
import numpy as np
import matplotlib.gridspec as gridspec
from matplotlib import animation, rc
rc('animation', html='html5')

###########

fig = plt.figure(figsize=(10, 10),facecolor='white')
gs = gridspec.GridSpec(1, 1)

#############################

ax1 = plt.subplot(gs[0,0])

lonmm,latmm=np.meshgrid(lon,lat)

map = Basemap(projection='ortho',lat_0=mean(lat),lon_0=mean(lon),resolution='c',ax=ax1)
lonm,latm=map(lonmm,latmm)
map.drawmeridians(np.arange(0,360,30),labels=[1,1,0,0],fontsize=10)
map.drawparallels(np.arange(0,360,30),labels=[1,1,0,0],fontsize=10)
map.fillcontinents(color='black',lake_color='black')
map.drawcoastlines()
map.drawcoastlines()

#quad2 = ax1.pcolormesh(lonm,latm,eddyfield[0,:,:],shading='gouraud',cmap=cm.cm.balance,\
#              vmin=-40,vmax=40)


def init():
    quad1.set_array([])
    quad2.set_array([])
    return quad1,quad2

def animate(iter):
    #ax1.contourf(lonm,latm,ssha[0,:,:],shading='gouraud',cmap=cm.cm.balance,vmin=-40,vmax=40,alpha=0.1)
    ax1.contourf(lonm,latm,ssha[iter,:,:],shading='gouraud',cmap=cm.cm.oxy,vmin=-40,vmax=40,alpha=0.5)
    ax1.contourf(lonm,latm,eddyfield[iter,:,:],shading='gouraud',cmap=cm.cm.balance,\
              vmin=-40,vmax=40,alpha=0.9)
    #quad2.set_array(ssha[iter,:,:].ravel())
    #quad1.set_array(eddyfield[iter,:,:].ravel())
    
    #ax1.pcolormesh(lonm,latm,eddyfield[iter,:,:],shading='gouraud',cmap=cm.cm.balance,vmin=-40,vmax=40,alpha=1)
    ax1.set_title('%03d'%(iter))
    
    #quad2.set_array(eddyfield[iter,:,:].ravel())
    return

gs.tight_layout(fig)

anim2 = animation.FuncAnimation(fig,animate,frames=60,interval=100,blit=False,repeat=True)
plt.close()
anim2
# Out:
# 'Warning: Cannot label meridians on full-disk
#                 Geostationary, Orthographic or Azimuthal equidistant basemap
#                 Warning: Cannot label parallels on Orthographic basemap
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# /g/data3/hh5/public/apps/miniconda3/envs/analysis3/lib/python3.6/site-packages/IPython/core/formatters.py in __call__(self, obj)
#     343             method = get_real_method(obj, self.print_method)
#     344             if method is not None:
# --> 345                 return method()
#     346             return None
#     347         else:
#
# ~/.local/lib/python3.6/site-packages/matplotlib/animation.py in _repr_html_(self)
#    1482         fmt = rcParams['animation.html']
#    1483         if fmt == 'html5':
# -> 1484             return self.to_html5_video()
#    1485         elif fmt == 'jshtml':
#    1486             return self.to_jshtml()
#
# ~/.local/lib/python3.6/site-packages/matplotlib/animation.py in to_html5_video(self, embed_limit)
#    1411                                 bitrate=rcParams['animation.bitrate'],
#    1412                                 fps=1000. / self._interval)
# -> 1413                 self.save(f.name, writer=writer)
#    1414
#    1415             # Now open and base64 encode
#
# ~/.local/lib/python3.6/site-packages/matplotlib/animation.py in save(self, filename, writer, fps, dpi, codec, bitrate, extra_args, metadata, extra_anim, savefig_kwargs)
#    1249                                level='helpful')
#    1250                 rcParams['savefig.bbox'] = None
# -> 1251             with writer.saving(self._fig, filename, dpi):
#    1252                 for anim in all_anim:
#    1253                     # Clear the initial frame
#
# /g/data3/hh5/public/apps/miniconda3/envs/analysis3/lib/python3.6/contextlib.py in __enter__(self)
#      79     def __enter__(self):
#      80         try:
# ---> 81             return next(self.gen)
#      82         except StopIteration:
#      83             raise RuntimeError("generator didn't yield") from None
#
# ~/.local/lib/python3.6/site-packages/matplotlib/animation.py in saving(self, fig, outfile, dpi, *args, **kwargs)
#     231         '''
#     232         # This particular sequence is what contextlib.contextmanager wants
# --> 233         self.setup(fig, outfile, dpi, *args, **kwargs)
#     234         try:
#     235             yield self
#
# ~/.local/lib/python3.6/site-packages/matplotlib/animation.py in setup(self, fig, outfile, dpi)
#     347         # Run here so that grab_frame() can write the data to a pipe. This
#     348         # eliminates the need for temp files.
# --> 349         self._run()
#     350
#     351     def _run(self):
#
# ~/.local/lib/python3.6/site-packages/matplotlib/animation.py in _run(self)
#     363                                       stdout=output, stderr=output,
#     364                                       stdin=subprocess.PIPE,
# --> 365                                       creationflags=subprocess_creation_flags)
#     366
#     367     def finish(self):
#
# /g/data3/hh5/public/apps/miniconda3/envs/analysis3/lib/python3.6/subprocess.py in __init__(self, args, bufsize, executable, stdin, stdout, stderr, preexec_fn, close_fds, shell, cwd, env, universal_newlines, startupinfo, creationflags, restore_signals, start_new_session, pass_fds, encoding, errors)
#     707                                 c2pread, c2pwrite,
#     708                                 errread, errwrite,
# --> 709                                 restore_signals, start_new_session)
#     710         except:
#     711             # Cleanup if the child failed starting.
#
# /g/data3/hh5/public/apps/miniconda3/envs/analysis3/lib/python3.6/subprocess.py in _execute_child(self, args, executable, preexec_fn, close_fds, pass_fds, cwd, env, startupinfo, creationflags, shell, p2cread, p2cwrite, c2pread, c2pwrite, errread, errwrite, restore_signals, start_new_session)
#    1273                             errread, errwrite,
#    1274                             errpipe_read, errpipe_write,
# -> 1275                             restore_signals, start_new_session, preexec_fn)
#    1276                     self._child_created = True
#    1277                 finally:
#
# OSError: [Errno 12] Cannot allocate memory

# %% [markdown]
# # Default Values
#
# Eccentricity Fit = 0.8
#
# Ellipse Fit = 0.5
#
# Gauss Fit = 0.5

# %%
eddytd=analyseddyzt(eta,lon,lat,0,60,1,25,5,5,data_meant=ssh_mean,areamap=areamap,mask=''\
                    ,destdir='',physics='',eccenfit=0.8,ellipsrsquarefit=0.5,gaussrsquarefit=0.5,\
                    diagnostics=False,pprint=False)
# Out:
#  0% [=========================================>]70% Time Elapsed: 164 s  Number of contours analysed: 4674
# ERROR:root:Internal Python error in the inspect module.
# Below is the traceback from this internal error.
# Traceback (most recent call last):
#   File "/g/data3/hh5/public/apps/miniconda3/envs/analysis3/lib/python3.6/site-packages/IPython/core/interactiveshell.py", line 2910, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "<ipython-input-31-f9cb565ef74c>", line 1, in <module>
#     eddytd=analyseddyzt(eta,lon,lat,0,60,1,25,5,5,data_meant=ssh_mean,areamap=areamap,mask=''                    ,destdir='',physics='',eccenfit=0.8,ellipsrsquarefit=0.5,gaussrsquarefit=0.5,                    diagnostics=False,pprint=False)
#   File "/home/156/jm5970/github/trackeddy/trackeddy/tracking.py", line 813, in analyseddyzt
#     ,diagnostics=diagnostics,plotdata=plotdata,pprint=pprint)
#   File "/home/156/jm5970/github/trackeddy/trackeddy/tracking.py", line 211, in scan_eddym
#     checkland=eddylandcheck(CONTeach,center,lon_contour,lat_contour,ssh_in_contour)
#   File "/home/156/jm5970/github/trackeddy/trackeddy/geometryfunc.py", line 873, in eddylandcheck
#     idxcheck,idycheck=find2l(lon,lat,contour[ii,0],contour[ii,1])
# KeyboardInterrupt
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/g/data3/hh5/public/apps/miniconda3/envs/analysis3/lib/python3.6/site-packages/IPython/core/interactiveshell.py", line 1828, in showtraceback
#     stb = value._render_traceback_()
# AttributeError: 'KeyboardInterrupt' object has no attribute '_render_traceback_'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/g/data3/hh5/public/apps/miniconda3/envs/analysis3/lib/python3.6/site-packages/IPython/core/ultratb.py", line 1090, in get_records
#     return _fixed_getinnerframes(etb, number_of_lines_of_context, tb_offset)
#   File "/g/data3/hh5/public/apps/miniconda3/envs/analysis3/lib/python3.6/site-packages/IPython/core/ultratb.py", line 311, in wrapped
#     return f(*args, **kwargs)
#   File "/g/data3/hh5/public/apps/miniconda3/envs/analysis3/lib/python3.6/site-packages/IPython/core/ultratb.py", line 345, in _fixed_getinnerframes
#     records = fix_frame_records_filenames(inspect.getinnerframes(etb, context))
#   File "/g/data3/hh5/public/apps/miniconda3/envs/analysis3/lib/python3.6/inspect.py", line 1483, in getinnerframes
#     frameinfo = (tb.tb_frame,) + getframeinfo(tb, context)
#   File "/g/data3/hh5/public/apps/miniconda3/envs/analysis3/lib/python3.6/inspect.py", line 1441, in getframeinfo
#     filename = getsourcefile(frame) or getfile(frame)
#   File "/g/data3/hh5/public/apps/miniconda3/envs/analysis3/lib/python3.6/inspect.py", line 696, in getsourcefile
#     if getattr(getmodule(object, filename), '__loader__', None) is not None:
#   File "/g/data3/hh5/public/apps/miniconda3/envs/analysis3/lib/python3.6/inspect.py", line 739, in getmodule
#     f = getabsfile(module)
#   File "/g/data3/hh5/public/apps/miniconda3/envs/analysis3/lib/python3.6/inspect.py", line 708, in getabsfile
#     _filename = getsourcefile(object) or getfile(object)
#   File "/g/data3/hh5/public/apps/miniconda3/envs/analysis3/lib/python3.6/inspect.py", line 693, in getsourcefile
#     if os.path.exists(filename):
#   File "/g/data3/hh5/public/apps/miniconda3/envs/analysis3/lib/python3.6/genericpath.py", line 19, in exists
#     os.stat(path)
# KeyboardInterrupt
# ---------------------------------------------------------------------------

# %%
eddytdn=analyseddyzt(eta,lon,lat,0,60,1,-25,-5,-5,data_meant=ssh_mean,areamap=areamap,mask=''\
                    ,destdir='',physics='',eccenfit=0.8,ellipsrsquarefit=0.5,gaussrsquarefit=0.5,\
                    diagnostics=False,pprint=False)

# %%
threshold=1
eddyp=reconstruct_syntetic(shape(eta),lon,lat,eddytd)
eddyp[eddyp>=5]=np.nan
eddyn=reconstruct_syntetic(shape(eta),lon,lat,eddytdn)
eddyn[eddyn<=-5]=np.nan
eddyfield=eddyp+eddyn

# %%
import matplotlib.pyplot as plt
import numpy as np
import matplotlib.gridspec as gridspec
from matplotlib import animation, rc
rc('animation', html='html5')

###########

fig = plt.figure(figsize=(10, 10),facecolor='white')
gs = gridspec.GridSpec(1, 1)

#############################

ax1 = plt.subplot(gs[0,0])

lonmm,latmm=np.meshgrid(lon,lat)

map = Basemap(projection='ortho',lat_0=mean(lat),lon_0=mean(lon),resolution='c',ax=ax1)
lonm,latm=map(lonmm,latmm)
map.drawmeridians(np.arange(0,360,30),labels=[1,1,0,0],fontsize=10)
map.drawparallels(np.arange(0,360,30),labels=[1,1,0,0],fontsize=10)
map.fillcontinents(color='black',lake_color='black')
map.drawcoastlines()
map.drawcoastlines()

#quad2 = ax1.pcolormesh(lonm,latm,eddyfield[0,:,:],shading='gouraud',cmap=cm.cm.balance,\
#              vmin=-40,vmax=40)


def init():
    quad1.set_array([])
    quad2.set_array([])
    return quad1,quad2

def animate(iter):
    #ax1.contourf(lonm,latm,ssha[0,:,:],shading='gouraud',cmap=cm.cm.balance,vmin=-40,vmax=40,alpha=0.1)
    ax1.contourf(lonm,latm,ssha[iter,:,:],shading='gouraud',cmap=cm.cm.oxy,vmin=-40,vmax=40,alpha=0.5)
    ax1.contourf(lonm,latm,eddyfield[iter,:,:],shading='gouraud',cmap=cm.cm.balance,\
              vmin=-40,vmax=40,alpha=0.9)
    #quad2.set_array(ssha[iter,:,:].ravel())
    #quad1.set_array(eddyfield[iter,:,:].ravel())
    
    #ax1.pcolormesh(lonm,latm,eddyfield[iter,:,:],shading='gouraud',cmap=cm.cm.balance,vmin=-40,vmax=40,alpha=1)
    ax1.set_title('%03d'%(iter))
    
    #quad2.set_array(eddyfield[iter,:,:].ravel())
    return

gs.tight_layout(fig)

anim2 = animation.FuncAnimation(fig,animate,frames=60,interval=100,blit=False,repeat=True)
plt.close()
anim2

# %% [markdown]
# # Default Values
#
# Eccentricity Fit = 1
#
# Ellipse Fit = 0.5
#
# Gauss Fit = 0.5

# %%
eddytd=analyseddyzt(eta,lon,lat,0,60,1,25,5,5,data_meant=ssh_mean,areamap=areamap,mask=''\
                    ,destdir='',physics='',eccenfit=1,ellipsrsquarefit=0.5,gaussrsquarefit=0.5,\
                    diagnostics=False,pprint=False)

# %%
eddytdn=analyseddyzt(eta,lon,lat,0,60,1,-25,-5,-5,data_meant=ssh_mean,areamap=areamap,mask=''\
                    ,destdir='',physics='',eccenfit=1,ellipsrsquarefit=0.5,gaussrsquarefit=0.5,\
                    diagnostics=False,pprint=False)

# %%
threshold=1
eddyp=reconstruct_syntetic(shape(eta),lon,lat,eddytd)
eddyp[eddyp>=5]=np.nan
eddyn=reconstruct_syntetic(shape(eta),lon,lat,eddytdn)
eddyn[eddyn<=-5]=np.nan
eddyfield=eddyp+eddyn

# %%
import matplotlib.pyplot as plt
import numpy as np
import matplotlib.gridspec as gridspec
from matplotlib import animation, rc
rc('animation', html='html5')

###########

fig = plt.figure(figsize=(10, 10),facecolor='white')
gs = gridspec.GridSpec(1, 1)

#############################

ax1 = plt.subplot(gs[0,0])

lonmm,latmm=np.meshgrid(lon,lat)

map = Basemap(projection='ortho',lat_0=mean(lat),lon_0=mean(lon),resolution='c',ax=ax1)
lonm,latm=map(lonmm,latmm)
map.drawmeridians(np.arange(0,360,30),labels=[1,1,0,0],fontsize=10)
map.drawparallels(np.arange(0,360,30),labels=[1,1,0,0],fontsize=10)
map.fillcontinents(color='black',lake_color='black')
map.drawcoastlines()
map.drawcoastlines()

#quad2 = ax1.pcolormesh(lonm,latm,eddyfield[0,:,:],shading='gouraud',cmap=cm.cm.balance,\
#              vmin=-40,vmax=40)


def init():
    quad1.set_array([])
    quad2.set_array([])
    return quad1,quad2

def animate(iter):
    #ax1.contourf(lonm,latm,ssha[0,:,:],shading='gouraud',cmap=cm.cm.balance,vmin=-40,vmax=40,alpha=0.1)
    ax1.contourf(lonm,latm,ssha[iter,:,:],shading='gouraud',cmap=cm.cm.oxy,vmin=-40,vmax=40,alpha=0.5)
    ax1.contourf(lonm,latm,eddyfield[iter,:,:],shading='gouraud',cmap=cm.cm.balance,\
              vmin=-40,vmax=40,alpha=0.9)
    #quad2.set_array(ssha[iter,:,:].ravel())
    #quad1.set_array(eddyfield[iter,:,:].ravel())
    
    #ax1.pcolormesh(lonm,latm,eddyfield[iter,:,:],shading='gouraud',cmap=cm.cm.balance,vmin=-40,vmax=40,alpha=1)
    ax1.set_title('%03d'%(iter))
    
    #quad2.set_array(eddyfield[iter,:,:].ravel())
    return

gs.tight_layout(fig)

anim2 = animation.FuncAnimation(fig,animate,frames=60,interval=100,blit=False,repeat=True)
plt.close()
anim2

# %% [markdown]
# # Default Values
#
# Eccentricity Fit = 1
#
# Ellipse Fit = 0
#
# Gauss Fit = 0

# %%
eddytd=analyseddyzt(eta,lon,lat,0,60,1,25,5,5,data_meant=ssh_mean,areamap=areamap,mask=''\
                    ,destdir='',physics='',eccenfit=1,ellipsrsquarefit=0,gaussrsquarefit=0,\
                    diagnostics=False,pprint=False)

# %%
eddytdn=analyseddyzt(eta,lon,lat,0,60,1,-25,-5,-5,data_meant=ssh_mean,areamap=areamap,mask=''\
                    ,destdir='',physics='',eccenfit=1,ellipsrsquarefit=0,gaussrsquarefit=0,\
                    diagnostics=False,pprint=False)

# %%
threshold=1
eddyp=reconstruct_syntetic(shape(eta),lon,lat,eddytd)
eddyp[eddyp>=5]=np.nan
eddyn=reconstruct_syntetic(shape(eta),lon,lat,eddytdn)
eddyn[eddyn<=-5]=np.nan
eddyfield=eddyp+eddyn

# %%
import matplotlib.pyplot as plt
import numpy as np
import matplotlib.gridspec as gridspec
from matplotlib import animation, rc
rc('animation', html='html5')

###########

fig = plt.figure(figsize=(10, 10),facecolor='white')
gs = gridspec.GridSpec(1, 1)

#############################

ax1 = plt.subplot(gs[0,0])

lonmm,latmm=np.meshgrid(lon,lat)

map = Basemap(projection='ortho',lat_0=mean(lat),lon_0=mean(lon),resolution='c',ax=ax1)
lonm,latm=map(lonmm,latmm)
map.drawmeridians(np.arange(0,360,30),labels=[1,1,0,0],fontsize=10)
map.drawparallels(np.arange(0,360,30),labels=[1,1,0,0],fontsize=10)
map.fillcontinents(color='black',lake_color='black')
map.drawcoastlines()
map.drawcoastlines()

#quad2 = ax1.pcolormesh(lonm,latm,eddyfield[0,:,:],shading='gouraud',cmap=cm.cm.balance,\
#              vmin=-40,vmax=40)


def init():
    quad1.set_array([])
    quad2.set_array([])
    return quad1,quad2

def animate(iter):
    #ax1.contourf(lonm,latm,ssha[0,:,:],shading='gouraud',cmap=cm.cm.balance,vmin=-40,vmax=40,alpha=0.1)
    ax1.contourf(lonm,latm,ssha[iter,:,:],shading='gouraud',cmap=cm.cm.oxy,vmin=-40,vmax=40,alpha=0.5)
    ax1.contourf(lonm,latm,eddyfield[iter,:,:],shading='gouraud',cmap=cm.cm.balance,\
              vmin=-40,vmax=40,alpha=0.9)
    #quad2.set_array(ssha[iter,:,:].ravel())
    #quad1.set_array(eddyfield[iter,:,:].ravel())
    
    #ax1.pcolormesh(lonm,latm,eddyfield[iter,:,:],shading='gouraud',cmap=cm.cm.balance,vmin=-40,vmax=40,alpha=1)
    ax1.set_title('%03d'%(iter))
    
    #quad2.set_array(eddyfield[iter,:,:].ravel())
    return

gs.tight_layout(fig)

anim2 = animation.FuncAnimation(fig,animate,frames=60,interval=100,blit=False,repeat=True)
plt.close()
anim2
